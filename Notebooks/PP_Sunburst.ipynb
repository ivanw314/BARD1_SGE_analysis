# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

vampseq_folder = '../Data/filtered_ppj_data/VAMPseq'
sge_folder = "../Data/filtered_ppj_data/SGE"

vampseq_genes = ['F9', 'TSC2', 'G6PD']
sge_genes = ['BRCA2', 'PALB2', 'CTCF', 'XRCC2', 'RAD51D', 'BARD1', 'SFPQ']

vampseq_files = {'F9': ['../Data/filtered_ppj_data/VAMPseq/F9_ab001.csv'],
                 'G6PD': ['../Data/filtered_ppj_data/VAMPseq/G6PD_scores_consequence.csv'],
                 'TSC2': ['../Data/filtered_ppj_data/VAMPseq/TSC2_scores_consequences.csv']
                }

# %%
def read_data(vamp, sge):

    vampseq = Path(vamp)
    sge = Path(sge)

    sge_files = list(sge.glob("*tsv*"))
    
    vampseq_data = {}
    sge_data = {}

    f9_data = []

    for gene in sge_genes:
        for elem in sge_files:
            if gene in str(elem):
                df = pd.read_csv(elem, sep = '\t')
                df = df.loc[df['variant_qc_flag'] != 'WARN']
                sge_data[gene] = df


    for gene in vampseq_genes:
        file_list = vampseq_files[gene]

        for file in file_list:
            df = pd.read_csv(file)
            if gene == 'F9':
                f9_data.append(df)
            else:
                vampseq_data[gene] = df



    vampseq_data['F9'] = f9_data

    return vampseq_data, sge_data

# %%
def assay_comparison_rings(sge_data, vampseq_data):
    # Calculate totals
    sge_total_genomic = sum([len(set(sge_data[g]['pos'])) for g in sge_data])
    sge_total_amino = sum([len(set(sge_data[g]['amino_acid_change'])) for g in sge_data])
    
    vamp_total_genomic = 0
    vamp_total_amino = 0
    for gene in vampseq_data:
        df = vampseq_data[gene]
        if gene == 'F9':
            df = df[0]
        vamp_total_genomic += len(set(df['position'])) * 3
        vamp_total_amino += len(df)
    
    # Get gene lists
    sge_genes = list(sge_data.keys())
    vamp_genes = list(vampseq_data.keys())
    
    # Fixed parameters
    gene_ring_thickness = 0.15
    center_hole = 0.3
    scale = 0.00001  # Adjust this to control overall ring thickness
    
    # Use absolute values (no normalization!)
    sge_genomic_thickness = sge_total_genomic * scale
    sge_amino_thickness = sge_total_amino * scale
    
    vamp_genomic_thickness = vamp_total_genomic * scale
    vamp_amino_thickness = vamp_total_amino * scale
    
    # Calculate max radius
    center_radius = center_hole + gene_ring_thickness
    sge_max = center_radius + sge_genomic_thickness + sge_amino_thickness
    vamp_max = center_radius + vamp_genomic_thickness + vamp_amino_thickness
    max_radius = max(sge_max, vamp_max) + 0.2
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 7), subplot_kw=dict(projection='polar'))
    
    # ===== SGE RINGS =====
    ax1 = axes[0]
    theta = np.linspace(0, 2*np.pi, 100)
    
    # Gene ring (innermost)
    num_sge_genes = len(sge_genes)
    gene_colors = plt.cm.Set3(np.linspace(0, 1, num_sge_genes))
    
    sge_gene_values = [len(sge_data[g]) for g in sge_genes]
    sge_gene_total = sum(sge_gene_values)
    
    for i, gene in enumerate(sge_genes):
        # Calculate proportional theta ranges
        theta_start = sum(sge_gene_values[:i]) / sge_gene_total * 2 * np.pi
        theta_end = sum(sge_gene_values[:i+1]) / sge_gene_total * 2 * np.pi
        theta_gene = np.linspace(theta_start, theta_end, 50)
        
        ax1.fill_between(theta_gene, center_hole, center_radius, 
                        color=gene_colors[i], alpha=0.9, linewidth=0)
        
        # Add gene label (only if wedge is big enough)
        if (theta_end - theta_start) > 0.2:
            theta_mid = (theta_start + theta_end) / 2
            ax1.text(theta_mid, (center_hole + center_radius) / 2, gene, 
                    ha='center', va='center', fontsize=7, fontweight='bold')
    
    # Genomic ring
    genomic_inner = center_radius
    genomic_outer = genomic_inner + sge_genomic_thickness
    ax1.fill_between(theta, genomic_inner, genomic_outer, color='steelblue', alpha=0.8, 
                     label=f'Genomic ({sge_total_genomic:,})', linewidth=0)
    
    # Amino acid ring
    amino_inner = genomic_outer
    amino_outer = amino_inner + sge_amino_thickness
    ax1.fill_between(theta, amino_inner, amino_outer, color='navy', alpha=0.8, 
                     label=f'Amino acid ({sge_total_amino:,})', linewidth=0)
    
    ax1.set_ylim(0, max_radius)
    ax1.set_title('SGE', fontsize=18, fontweight='bold', pad=20)
    ax1.set_yticks([])
    ax1.set_xticks([])
    ax1.spines['polar'].set_visible(False)
    ax1.grid(False)
    ax1.legend(loc='upper left', bbox_to_anchor=(-0.1, 1.1), frameon=False)
    
    # ===== VAMP-SEQ RINGS =====
    ax2 = axes[1]
    
    # Gene ring (innermost)
    num_vamp_genes = len(vamp_genes)
    vamp_gene_colors = plt.cm.Set3(np.linspace(0, 1, num_vamp_genes))

    vamp_gene_values = [len(vampseq_data[g]) if g != 'F9' else len(vampseq_data[g][0]) for g in vamp_genes]
    vamp_gene_total = sum(vamp_gene_values)
    
    for i, gene in enumerate(vamp_genes):
        # Calculate proportional theta ranges
        theta_start = sum(vamp_gene_values[:i]) / vamp_gene_total * 2 * np.pi
        theta_end = sum(vamp_gene_values[:i+1]) / vamp_gene_total * 2 * np.pi
        theta_gene = np.linspace(theta_start, theta_end, 50)
        
        ax2.fill_between(theta_gene, center_hole, center_radius,
                        color=vamp_gene_colors[i], alpha=0.9, linewidth=0)
        
        # Add gene label (only if wedge is big enough)
        if (theta_end - theta_start) > 0.2:
            theta_mid = (theta_start + theta_end) / 2
            ax2.text(theta_mid, (center_hole + center_radius) / 2, gene,
                    ha='center', va='center', fontsize=7, fontweight='bold')
        
    # Genomic ring
    genomic_inner_vamp = center_radius
    genomic_outer_vamp = genomic_inner_vamp + vamp_genomic_thickness
    ax2.fill_between(theta, genomic_inner_vamp, genomic_outer_vamp, color='steelblue', alpha=0.8, 
                     label=f'Genomic ({vamp_total_genomic:,})', linewidth=0)
    
    # Amino acid ring
    amino_inner_vamp = genomic_outer_vamp
    amino_outer_vamp = amino_inner_vamp + vamp_amino_thickness
    ax2.fill_between(theta, amino_inner_vamp, amino_outer_vamp, color='navy', alpha=0.8, 
                     label=f'Amino acid ({vamp_total_amino:,})', linewidth=0)
    
    ax2.set_ylim(0, max_radius)
    ax2.set_title('VAMP-seq', fontsize=18, fontweight='bold', pad=20)
    ax2.set_yticks([])
    ax2.set_xticks([])
    ax2.spines['polar'].set_visible(False)
    ax2.grid(False)
    ax2.legend(loc='upper left', bbox_to_anchor=(-0.1, 1.1), frameon=False)
    
    plt.tight_layout()
    plt.show()

    #fig .savefig('/Users/ivan/Desktop/pillar_project_figs/20251114_NestedDonuts.svg')

# %%
def main():
    vampseq_data, sge_data = read_data(vampseq_folder, sge_folder)
    assay_comparison_rings(sge_data, vampseq_data)

# %%
main()
