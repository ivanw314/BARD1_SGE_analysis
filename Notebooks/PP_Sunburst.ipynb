# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
from matplotlib.patches import Polygon

vampseq_folder = '../Data/filtered_ppj_data/VAMPseq'
sge_folder = "../Data/filtered_ppj_data/SGE"

vampseq_genes = ['F9', 'TSC2', 'G6PD']
sge_genes = ['BRCA2', 'PALB2', 'CTCF', 'XRCC2', 'RAD51D', 'BARD1', 'SFPQ']

vampseq_files = {'F9': ['../Data/filtered_ppj_data/VAMPseq/F9_ab001.csv'],
                 'G6PD': ['../Data/filtered_ppj_data/VAMPseq/G6PD_scores_consequence.csv'],
                 'TSC2': ['../Data/filtered_ppj_data/VAMPseq/TSC2_scores_consequences.csv']
                }

# %%
def read_data(vamp, sge):

    vampseq = Path(vamp)
    sge = Path(sge)

    sge_files = list(sge.glob("*tsv*"))
    
    vampseq_data = {}
    sge_data = {}

    f9_data = []

    for gene in sge_genes:
        for elem in sge_files:
            if gene in str(elem):
                df = pd.read_csv(elem, sep = '\t')
                df = df.loc[df['variant_qc_flag'] != 'WARN']
                sge_data[gene] = df


    for gene in vampseq_genes:
        file_list = vampseq_files[gene]

        for file in file_list:
            df = pd.read_csv(file)
            if gene == 'F9':
                f9_data.append(df)
            else:
                vampseq_data[gene] = df



    vampseq_data['F9'] = f9_data

    return vampseq_data, sge_data

# %%
def assay_comparison_rings(sge_data, vampseq_data):
    # Calculate totals
    sge_total_genomic = sum([len(set(sge_data[g]['pos'])) for g in sge_data])
    sge_total_amino = sum([len(set(sge_data[g]['amino_acid_change'])) for g in sge_data])
    
    vamp_total_genomic = 0
    vamp_total_amino = 0
    for gene in vampseq_data:
        df = vampseq_data[gene]
        if gene == 'F9':
            df = df[0]
        vamp_total_genomic += len(set(df['position'])) * 3
        vamp_total_amino += len(df)
    
    # Get gene lists
    sge_genes = list(sge_data.keys())
    vamp_genes = list(vampseq_data.keys())
    
    # Fixed parameters
    gene_ring_thickness = 0.15
    center_hole = 0.3
    scale = 0.00001  # Adjust this to control overall ring thickness
    
    # Use absolute values (no normalization!)
    sge_genomic_thickness = sge_total_genomic * scale
    sge_amino_thickness = sge_total_amino * scale
    
    vamp_genomic_thickness = vamp_total_genomic * scale
    vamp_amino_thickness = vamp_total_amino * scale
    
    # Calculate max radius
    center_radius = center_hole + gene_ring_thickness
    sge_max = center_radius + sge_genomic_thickness + sge_amino_thickness
    vamp_max = center_radius + vamp_genomic_thickness + vamp_amino_thickness
    max_radius = max(sge_max, vamp_max) + 0.2
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 7), subplot_kw=dict(projection='polar'))
    
    # ===== SGE RINGS =====
    ax1 = axes[0]
    theta = np.linspace(0, 2*np.pi, 100)
    
    # Gene ring (innermost)
    num_sge_genes = len(sge_genes)
    gene_colors = plt.cm.Set3(np.linspace(0, 1, num_sge_genes))
    
    sge_gene_values = [len(sge_data[g]) for g in sge_genes]
    sge_gene_total = sum(sge_gene_values)
    
    for i, gene in enumerate(sge_genes):
        # Calculate proportional theta ranges
        theta_start = sum(sge_gene_values[:i]) / sge_gene_total * 2 * np.pi
        theta_end = sum(sge_gene_values[:i+1]) / sge_gene_total * 2 * np.pi
        theta_gene = np.linspace(theta_start, theta_end, 50)
        
        ax1.fill_between(theta_gene, center_hole, center_radius, 
                        color=gene_colors[i], alpha=0.9, linewidth=0)
        
        # Add gene label (only if wedge is big enough)
        if (theta_end - theta_start) > 0.2:
            theta_mid = (theta_start + theta_end) / 2
            ax1.text(theta_mid, (center_hole + center_radius) / 2, gene, 
                    ha='center', va='center', fontsize=7, fontweight='bold')
    
    # Genomic ring
    genomic_inner = center_radius
    genomic_outer = genomic_inner + sge_genomic_thickness
    ax1.fill_between(theta, genomic_inner, genomic_outer, color='steelblue', alpha=0.8, 
                     label=f'Genomic ({sge_total_genomic:,})', linewidth=0)
    
    # Amino acid ring
    amino_inner = genomic_outer
    amino_outer = amino_inner + sge_amino_thickness
    ax1.fill_between(theta, amino_inner, amino_outer, color='navy', alpha=0.8, 
                     label=f'Amino acid ({sge_total_amino:,})', linewidth=0)
    
    ax1.set_ylim(0, max_radius)
    ax1.set_title('SGE', fontsize=18, fontweight='bold', pad=20)
    ax1.set_yticks([])
    ax1.set_xticks([])
    ax1.spines['polar'].set_visible(False)
    ax1.grid(False)
    ax1.legend(loc='upper left', bbox_to_anchor=(-0.1, 1.1), frameon=False)
    
    # ===== VAMP-SEQ RINGS =====
    ax2 = axes[1]
    
    # Gene ring (innermost)
    num_vamp_genes = len(vamp_genes)
    vamp_gene_colors = plt.cm.Set3(np.linspace(0, 1, num_vamp_genes))

    vamp_gene_values = [len(vampseq_data[g]) if g != 'F9' else len(vampseq_data[g][0]) for g in vamp_genes]
    vamp_gene_total = sum(vamp_gene_values)
    
    for i, gene in enumerate(vamp_genes):
        # Calculate proportional theta ranges
        theta_start = sum(vamp_gene_values[:i]) / vamp_gene_total * 2 * np.pi
        theta_end = sum(vamp_gene_values[:i+1]) / vamp_gene_total * 2 * np.pi
        theta_gene = np.linspace(theta_start, theta_end, 50)
        
        ax2.fill_between(theta_gene, center_hole, center_radius,
                        color=vamp_gene_colors[i], alpha=0.9, linewidth=0)
        
        # Add gene label (only if wedge is big enough)
        if (theta_end - theta_start) > 0.2:
            theta_mid = (theta_start + theta_end) / 2
            ax2.text(theta_mid, (center_hole + center_radius) / 2, gene,
                    ha='center', va='center', fontsize=7, fontweight='bold')
        
    # Genomic ring
    genomic_inner_vamp = center_radius
    genomic_outer_vamp = genomic_inner_vamp + vamp_genomic_thickness
    ax2.fill_between(theta, genomic_inner_vamp, genomic_outer_vamp, color='steelblue', alpha=0.8, 
                     label=f'Genomic ({vamp_total_genomic:,})', linewidth=0)
    
    # Amino acid ring
    amino_inner_vamp = genomic_outer_vamp
    amino_outer_vamp = amino_inner_vamp + vamp_amino_thickness
    ax2.fill_between(theta, amino_inner_vamp, amino_outer_vamp, color='navy', alpha=0.8, 
                     label=f'Amino acid ({vamp_total_amino:,})', linewidth=0)
    
    ax2.set_ylim(0, max_radius)
    ax2.set_title('VAMP-seq', fontsize=18, fontweight='bold', pad=20)
    ax2.set_yticks([])
    ax2.set_xticks([])
    ax2.spines['polar'].set_visible(False)
    ax2.grid(False)
    ax2.legend(loc='upper left', bbox_to_anchor=(-0.1, 1.1), frameon=False)
    
    plt.tight_layout()
    plt.show()

    #fig .savefig('/Users/ivan/Desktop/pillar_project_figs/20251114_NestedDonuts.svg')

# %%
def assay_comparison_bars(sge_data, vampseq_data):
    # Calculate totals
    sge_total_genomic = sum([len(set(sge_data[g]['pos'])) for g in sge_data])
    sge_total_amino = sum([len(set(sge_data[g]['amino_acid_change'])) for g in sge_data])
    
    vamp_total_genomic = 0
    vamp_total_amino = 0
    for gene in vampseq_data:
        df = vampseq_data[gene]
        if gene == 'F9':
            df = df[0]
        vamp_total_genomic += len(set(df['position'])) * 3
        vamp_total_amino += len(df)
    
    # Data for stacked bar
    assays = ['SGE', 'VAMP-seq']
    genomic = [sge_total_genomic, vamp_total_genomic]
    amino_acid = [sge_total_amino, vamp_total_amino]
    
    fig, ax = plt.subplots(figsize=(8, 6))
    
    # Create stacked bars
    x = np.arange(len(assays))
    width = 0.6
    
    p1 = ax.bar(x, genomic, width, label='Genomic positions', color='#A8DADC', alpha=0.9)
    p2 = ax.bar(x, amino_acid, width, bottom=genomic, label='Amino acid changes', color='#457B9D', alpha=0.9)
    
    # Formatting
    ax.set_ylabel('Count', fontsize=14, fontweight='bold')
    ax.set_title('Assay Coverage Comparison', fontsize=16, fontweight='bold', pad=20)
    ax.set_xticks(x)
    ax.set_xticklabels(assays, fontsize=14, fontweight='bold')
    ax.legend(fontsize=12, frameon=False, loc = 'upper right', bbox_to_anchor = (1.1, 1.05))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Add value labels on bars
    for i, (g, a) in enumerate(zip(genomic, amino_acid)):
        ax.text(i, g/2, f'{g:,}', ha='center', va='center', fontsize=10, fontweight='bold', color='black')
        ax.text(i, g + a/2, f'{a:,}', ha='center', va='center', fontsize=10, fontweight='bold', color='white')
    
    plt.tight_layout()
    plt.show()

# %%
from matplotlib.patches import Polygon

def assay_comparison_bars_wlines(sge_data, vampseq_data):
    # Calculate totals
    sge_total_genomic = sum([len(set(sge_data[g]['pos'])) for g in sge_data])
    sge_total_amino = sum([len(set(sge_data[g]['amino_acid_change'])) for g in sge_data])
    
    vamp_total_genomic = 0
    vamp_total_amino = 0
    for gene in vampseq_data:
        df = vampseq_data[gene]
        if gene == 'F9':
            df = df[0]
        vamp_total_genomic += len(set(df['position'])) * 3
        vamp_total_amino += len(df)
    
    # Data for stacked bar
    assays = ['SGE', 'VAMP-seq']
    genomic = [sge_total_genomic, vamp_total_genomic]
    amino_acid = [sge_total_amino, vamp_total_amino]
    
    fig, ax = plt.subplots(figsize=(8, 6))
    
    # Create stacked bars
    x = np.arange(len(assays))
    width = 0.6
    
    p1 = ax.bar(x, genomic, width, label='Genomic positions', color='#A8DADC', alpha=0.9)
    p2 = ax.bar(x, amino_acid, width, bottom=genomic, label='Amino acid changes', color='#457B9D', alpha=0.9)
    
    # Add connecting lines between genomic sections
    # Genomic line (bottom section)
    genomic_left_top = genomic[0]
    genomic_left_bottom = 0
    genomic_right_top = genomic[1]
    genomic_right_bottom = 0
    
    poly_genomic = Polygon([
        (x[0] + width/2, genomic_left_bottom),
        (x[0] + width/2, genomic_left_top),
        (x[1] - width/2, genomic_right_top),
        (x[1] - width/2, genomic_right_bottom)
    ], facecolor='#A8DADC', alpha=0.3, edgecolor='none')
    ax.add_patch(poly_genomic)
    
    # Amino acid line (top section)
    amino_left_bottom = genomic[0]
    amino_left_top = genomic[0] + amino_acid[0]
    amino_right_bottom = genomic[1]
    amino_right_top = genomic[1] + amino_acid[1]
    
    poly_amino = Polygon([
        (x[0] + width/2, amino_left_bottom),
        (x[0] + width/2, amino_left_top),
        (x[1] - width/2, amino_right_top),
        (x[1] - width/2, amino_right_bottom)
    ], facecolor='#457B9D', alpha=0.3, edgecolor='none')
    ax.add_patch(poly_amino)
    
    # Formatting
    ax.set_ylabel('Count', fontsize=14, fontweight='bold')
    ax.set_title('Assay Coverage Comparison', fontsize=16, fontweight='bold', pad=20)
    ax.set_xticks(x)
    ax.set_xticklabels(assays, fontsize=14, fontweight='bold')
    ax.legend(fontsize=12, frameon=False, loc='upper left', bbox_to_anchor=(1.05, 1))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Add value labels on bars
    for i, (g, a) in enumerate(zip(genomic, amino_acid)):
        ax.text(i, g/2, f'{g:,}', ha='center', va='center', fontsize=10, fontweight='bold', color='black')
        ax.text(i, g + a/2, f'{a:,}', ha='center', va='center', fontsize=10, fontweight='bold', color='white')
    
    plt.tight_layout()
    plt.show()

# %%
def assay_comparison_bars_by_gene(sge_data, vampseq_data):
    # Collect all genes and their values
    all_genes = []
    genomic_values = []
    amino_values = []
    assay_labels = []
    
    # SGE genes
    for gene in sge_data.keys():
        all_genes.append(f'{gene}\n(SGE)')
        genomic_values.append(len(set(sge_data[gene]['pos'])))
        amino_values.append(len(set(sge_data[gene]['amino_acid_change'])))
        assay_labels.append('SGE')
    
    # VAMP-seq genes
    for gene in vampseq_data.keys():
        df = vampseq_data[gene]
        if gene == 'F9':
            df = df[0]
        all_genes.append(f'{gene}\n(VAMP-seq)')
        genomic_values.append(len(set(df['position'])) * 3)
        amino_values.append(len(df))
        assay_labels.append('VAMP-seq')
    
    fig, ax = plt.subplots(figsize=(14, 6))
    
    x = np.arange(len(all_genes))
    width = 0.7
    
    # Create stacked bars
    p1 = ax.bar(x, genomic_values, width, label='Genomic positions', color='#A8DADC', alpha=0.9)
    p2 = ax.bar(x, amino_values, width, bottom=genomic_values, label='Amino acid changes', color='#457B9D', alpha=0.9)
    
    # Color code by assay
    colors = ['#A8DADC' if label == 'SGE' else '#F4A261' for label in assay_labels]
    for i, (bar, color) in enumerate(zip(p1, colors)):
        bar.set_color(color)
    
    amino_colors = ['#457B9D' if label == 'SGE' else '#E76F51' for label in assay_labels]
    for i, (bar, color) in enumerate(zip(p2, amino_colors)):
        bar.set_color(color)
    
    # Formatting
    ax.set_ylabel('Count', fontsize=14, fontweight='bold')
    ax.set_title('Coverage by Gene and Assay', fontsize=16, fontweight='bold', pad=20)
    ax.set_xticks(x)
    ax.set_xticklabels(all_genes, fontsize=9, rotation=45, ha='right')
    ax.legend(fontsize=12, frameon=False, loc='upper left')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    plt.tight_layout()
    plt.show()

# %%
def assay_comparison_bars_swapped(sge_data, vampseq_data):
    # Calculate totals
    sge_total_genomic = sum([len(set(sge_data[g]['pos'])) for g in sge_data])
    sge_total_amino = sum([len(set(sge_data[g]['amino_acid_change'])) for g in sge_data])
    
    vamp_total_genomic = 0
    vamp_total_amino = 0
    for gene in vampseq_data:
        df = vampseq_data[gene]
        if gene == 'F9':
            df = df[0]
        vamp_total_genomic += len(set(df['position'])) * 3
        vamp_total_amino += len(df)
    
    # Data for stacked bars - swapped order
    categories = ['Genomic positions', 'Amino acid changes']
    sge_values = [sge_total_genomic, sge_total_amino]
    vamp_values = [vamp_total_genomic, vamp_total_amino]
    
    fig, ax = plt.subplots(figsize=(8, 3))
    
    # Create horizontal stacked bars - VAMP-seq first, then SGE
    y = np.arange(len(categories))
    height = 0.6
    
    p1 = ax.barh(y, vamp_values, height, label='VAMP-seq', color='#F4A261', alpha=0.9)
    p2 = ax.barh(y, sge_values, height, left=vamp_values, label='SGE', color='#A8DADC', alpha=0.9)
    
    # Add connecting polygons - VAMP-seq sections (now on bottom)
    vamp_genomic_left = vamp_values[0]
    vamp_genomic_right = vamp_values[1]
    
    poly_vamp = Polygon([
        (0, y[0] + height/2),
        (vamp_genomic_left, y[0] + height/2),
        (vamp_genomic_right, y[1] - height/2),
        (0, y[1] - height/2)
    ], facecolor='#F4A261', alpha=0.3, edgecolor='none')
    ax.add_patch(poly_vamp)
    
    # SGE sections (now on top)
    sge_genomic_bottom_left = vamp_values[0]
    sge_genomic_top_left = vamp_values[0] + sge_values[0]
    sge_amino_bottom_right = vamp_values[1]
    sge_amino_top_right = vamp_values[1] + sge_values[1]
    
    poly_sge = Polygon([
        (sge_genomic_bottom_left, y[0] + height/2),
        (sge_genomic_top_left, y[0] + height/2),
        (sge_amino_top_right, y[1] - height/2),
        (sge_amino_bottom_right, y[1] - height/2)
    ], facecolor='#A8DADC', alpha=0.3, edgecolor='none')
    ax.add_patch(poly_sge)
    
    # Formatting
    ax.set_xlabel('Count', fontsize=14, fontweight='bold')
    ax.set_title('Assay Coverage Comparison', fontsize=16, fontweight='bold', pad=20)
    ax.set_yticks(y)
    ax.set_yticklabels(categories, fontsize=12, fontweight='bold')
    ax.legend(fontsize=12, frameon=False, loc='lower right')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Reduce space between bars
    ax.set_ylim(-0.5, len(categories) - 0.5)
    
    # Add value labels on bars - swapped order
    for i, (v, s) in enumerate(zip(vamp_values, sge_values)):
        ax.text(v/2, i, f'{v:,}', ha='center', va='center', fontsize=10, fontweight='bold', color='black')
        ax.text(v + s/2, i, f'{s:,}', ha='center', va='center', fontsize=10, fontweight='bold', color='black')
    
    plt.tight_layout()
    plt.show()
    #fig.savefig('/Users/ivan/Desktop/pillar_project_figs/20251121_vampseq_sge_bars.svg')

# %%
def main():
    vampseq_data, sge_data = read_data(vampseq_folder, sge_folder)
    #assay_comparison_rings(sge_data, vampseq_data)
    #assay_comparison_bars(sge_data, vampseq_data)
    assay_comparison_bars_wlines(sge_data, vampseq_data)
    assay_comparison_bars_by_gene(sge_data, vampseq_data)
    assay_comparison_bars_swapped(sge_data, vampseq_data)

# %%
main()
